# %%
############################################## Import Libraries ########################################################
import kagglehub
from os import path

path=kagglehub.dataset_download("saeeddehghani/wine-quality-merged")
# Out:
# ...
# 100%|██████████| 100k/100k [00:00<00:00, 47.4MB/s]
# Extracting files...

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,accuracy_score

# %%
############################################## DataFrame Load ##########################################################

# %%
df=pd.read_csv(f"{path}/wine_quality_merged.csv")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df["type"]=df["type"].replace('red', 0).replace('white', 1)
df["type"]
# Out:
# /tmp/ipython-input-373655423.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["type"]=df["type"].replace('red', 0).replace('white', 1)
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 6492    1
# 6493    1
# 6494    1
# 6495    1
# 6496    1
# Name: type, Length: 6497, dtype: int64

# %%
# Create x and y

x=df[df.columns[:-1]]
y= df["type"]

# %%
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=20)

# %%
# Call All The Models

KNN_model=KNeighborsClassifier()
NB_model=GaussianNB()
LR_model=LogisticRegression()
SVM_model=SVC()

# %%
# Training

KNN_model.fit(x_train,y_train)
NB_model.fit(x_train,y_train)
LR_model.fit(x_train,y_train)
SVM_model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# SVC()

# %%
# Testing

y_pred_KNN=KNN_model.predict(x_test)
y_pred_NB=NB_model.predict(x_test)
y_pred_LR=LR_model.predict(x_test)
y_pred_SVM=SVM_model.predict(x_test)

# %%
# Classification Reports

# %%
print(classification_report(y_test,y_pred_KNN))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.88      0.90       321
#            1       0.96      0.97      0.97       979
#
#     accuracy                           0.95      1300
#    macro avg       0.94      0.93      0.93      1300
# weighted avg       0.95      0.95      0.95      1300

# %%
print(classification_report(y_test,y_pred_NB))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94       321
#            1       0.99      0.97      0.98       979
#
#     accuracy                           0.97      1300
#    macro avg       0.95      0.97      0.96      1300
# weighted avg       0.97      0.97      0.97      1300

# %%
print(classification_report(y_test,y_pred_LR))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.97       321
#            1       0.98      0.99      0.99       979
#
#     accuracy                           0.98      1300
#    macro avg       0.98      0.97      0.98      1300
# weighted avg       0.98      0.98      0.98      1300

# %%
print(classification_report(y_test,y_pred_SVM))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.81      0.88       321
#            1       0.94      0.99      0.96       979
#
#     accuracy                           0.94      1300
#    macro avg       0.95      0.90      0.92      1300
# weighted avg       0.94      0.94      0.94      1300

# %%
# Create Pickle File
import pickle as pkl
with open("Accurate_wine_quality.pkl","wb") as f :
  pkl.dump(SVM_model,f)

# %%
# Load Pickle File
with open("Accurate_wine_quality.pkl","rb") as f:
  loaded_file = pkl.load(f)

# %%
loaded_file
# Out:
# SVC()

# %%
# Perform Loaded File
loaded_file.predict([x.iloc[0].values])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# array([0])
